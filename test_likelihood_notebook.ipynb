# %%
import jax.numpy as jnp
import jax
import equinox as eqx
import cryojax as cx
import src.ensemble_sim as sim
import os

import numpyro
import numpyro.distributions as dist

import logging
from functools import partial

import matplotlib.pyplot as plt
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ["XLA_PYTHON_CLIENT_PREALLOCATE"]="False"
os.environ["XLA_PYTHON_CLIENT_ALLOCATOR"]="platform"
#os.environ['CUDA_VISIBLE_DEVICES'] = ''   # To enable CPU backend

from jax.extend import backend
print("Device : ", backend.get_backend().platform)
# Out:
# Device :  gpu

# %% [markdown]
# # Create list of pdb files for simulating images from

# %%
path_to_models="data/hsp90_models"
model_fnames = []
for model_fname in sorted(os.listdir(path_to_models)):
    model_fnames.append(model_fname)

# %% [markdown]
# # Define a weight distribution on the pdb files
# ## Here, evaluating a gaussian mixture pdf on the indices of the pdbs

# %%
def GaussianMixture1D(weights, means, std_devs):
    weights = jnp.array(weights)
    means = jnp.array(means)
    std_devs = jnp.array(std_devs)
    mixing_dist = dist.Categorical(probs=weights/jnp.sum(weights))
    component_dist = dist.Normal(loc=means, scale=std_devs) 
    return dist.MixtureSameFamily(mixing_dist, component_dist) 

weights = [1., 1./3.]
means = [6., 15.]
std_devs = [2.0, 3.0]
mixture = GaussianMixture1D(weights, means, std_devs)
samples = mixture.sample(jax.random.PRNGKey(0), (10000,))
 
# compute pdf output on a 1d grid
x = jnp.linspace(0, 19, 20)
dx = x[1] - x[0]
    
# normalize output to integrate to 1 on the grid 
weights = jnp.exp(mixture.log_prob(x))
weights /= dx*weights.sum() 
plt.plot(x, weights, label='true', color="C0")
plt.xticks(jnp.arange(0, 20, 2))
plt.xlabel('pdb index')
plt.ylabel('Probability')  
plt.legend()
plt.show()

# %% [markdown]
# # Define a config file for image simulation

# %%
# Bare bones config for this notebook
# Things that may need to be adjusted:
#   number of images, noise_snr
# Everything else, unlikely

config = {
"number_of_images": 100,
"noise_snr": 0.1,
"weights_models": weights,
"models_fnames": model_fnames, 
"path_to_models": path_to_models, 
"box_size": 128,
"rng_seed": 0,
"pixel_size": 1.6,
}

# %%
# Create static image formation stuff
imaging_args = sim.build_image_formation_stuff(config)

# Create noise stuff
noise_grid = jnp.linspace(
                 -0.5 * (config["box_size"] - 1),
                 0.5 * (config["box_size"] - 1),
                 config["box_size"],
             )
noise_radius = 0.5*config["box_size"] - 1 # For now, using a disc that is radius of the image for SNR calculations
noise_args = noise_grid, noise_radius, config["noise_snr"] 

def get_pipeline_info(imaging_pipeline):
    """Custom function for returning various stats from an imaging pipeline"""
    info = {}
    info["conformation"] = imaging_pipeline.scattering_theory.structural_ensemble.conformation.value  
    #info["..."] = ...

    return info

# NOTE: here there is no argument at all for weights, since the weight dist is defined in config
def sample_images(key, config, imaging_args, noise_args):

    # Generate RNG keys for individual images
    key, *subkeys = jax.random.split(key, config["number_of_images"] + 1)
    subkeys = jnp.array(subkeys)
    
    # Pipeline
    # NOTE: these extra `eqx.combine' lines are just here because we are paying the piper for having very specific vmaps 
    imaging_pipeline_vmap, imaging_pipeline_novmap = sim.make_imaging_pipeline(subkeys, imaging_args)
    imaging_pipeline = eqx.combine(imaging_pipeline_vmap, imaging_pipeline_novmap)

    extra_info = get_pipeline_info(imaging_pipeline)

    noised_images, noise_power_sq = sim.compute_image_stack_with_noise(key, config, imaging_pipeline, noise_args)

    return noised_images, extra_info

# %% [markdown]
# # Simulate a dataset!

# %%
key = jax.random.PRNGKey(config["rng_seed"])
noised_images, extra_info = sample_images(key,config, imaging_args, noise_args)
# Out:
# 2025-03-26 15:15:34.594893: W external/xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.65GiB (rounded to 4996096000)requested by op
# 2025-03-26 15:15:34.595624: W external/xla/xla/tsl/framework/bfc_allocator.cc:512] *_____***********__**_____*_______________________________________________*_______________________**
# E0326 15:15:34.595648 3301454 pjrt_stream_executor_client.cc:3077] Execution of replica 0 failed: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 4996096000 bytes. [tf-allocator-allocation-error='']
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# Cell In[36], line 2
#       1 key = jax.random.PRNGKey(config["rng_seed"])
# ----> 2 noised_images, extra_info = sample_images(key,config, imaging_args, noise_args)
#
# Cell In[35], line 35, in sample_images(key, config, imaging_args, noise_args)
#      31 imaging_pipeline = eqx.combine(imaging_pipeline_vmap, imaging_pipeline_novmap)
#      33 extra_info = get_pipeline_info(imaging_pipeline)
# ---> 35 noised_images, noise_power_sq = sim.compute_image_stack_with_noise(key, config, imaging_pipeline, noise_args)
#      37 return noised_images, extra_info
#
# File ~/ensemble_sim/src/ensemble_sim.py:191, in compute_image_stack_with_noise(key, config, imaging_pipeline, noise_args)
#     189     return imaging_pipeline.render()
#     190 imaging_pipeline_vmap, imaging_pipeline_no_vmap = eqx.partition(imaging_pipeline, filter_spec)
# --> 191 images = compute_image_stack(imaging_pipeline_vmap, imaging_pipeline_no_vmap)
#     193 # Add noise to images
#     194 key, *subkeys = jax.random.split(key, config["number_of_images"] + 1)
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/equinox/_vmap_pmap.py:169, in _VmapWrapper.__call__(***failed resolving arguments***)
#     164         raise ValueError(
#     165             "Cannot resolve batch dimension. Non-`None` `out_axes` requires "
#     166             "either `in_axes` or `axis_size` to be not `None`."
#     167         )
#     168 else:
# --> 169     vmapd, nonvmapd_arr, static = jax.vmap(
#     170         _fun_wrapper,
#     171         in_axes=(in_axes,),
#     172         out_axes=(0, None, None),
#     173         axis_name=self._axis_name,
#     174         axis_size=self._axis_size,
#     175         **self._vmapkwargs,
#     176     )(dynamic_args)
#     178 nonvmapd_static, out_axes = static.value
#     179 nonvmapd = combine(nonvmapd_arr, nonvmapd_static)
#
#     [... skipping hidden 8 frame]
#
# File ~/ensemble_sim/src/ensemble_sim.py:189, in compute_image_stack_with_noise.<locals>.compute_image_stack(imaging_pipeline_vmap, imaging_pipeline_no_vmap)
#     186 @partial(eqx.filter_vmap, in_axes=(0, None), out_axes=0)
#     187 def compute_image_stack(imaging_pipeline_vmap, imaging_pipeline_no_vmap):
#     188     imaging_pipeline = eqx.combine(imaging_pipeline_vmap, imaging_pipeline_no_vmap)
# --> 189     return imaging_pipeline.render()
#
#     [... skipping hidden 1 frame]
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/cryojax/simulator/_imaging_pipeline.py:231, in ContrastImagingPipeline.render(self, rng_key, get_cropped, get_real, get_masked, get_filtered)
#     204 @override
#     205 def render(
#     206     self,
#    (...)    228 ):
#     229     # Compute the squared wavefunction
#     230     fourier_contrast_at_detector_plane = (
# --> 231         self.scattering_theory.compute_contrast_spectrum_at_detector_plane(
#     232             self.instrument_config, rng_key
#     233         )
#     234     )
#     236     return self._maybe_postprocess(
#     237         fourier_contrast_at_detector_plane,
#     238         get_cropped=get_cropped,
#    (...)    241         get_filtered=get_filtered,
#     242     )
#
#     [... skipping hidden 1 frame]
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/cryojax/simulator/_scattering_theory/weak_phase_scattering_theory.py:127, in WeakPhaseScatteringTheory.compute_contrast_spectrum_at_detector_plane(self, instrument_config, rng_key)
#     119 @override
#     120 def compute_contrast_spectrum_at_detector_plane(
#     121     self,
#    (...)    125     Array, "{instrument_config.padded_y_dim} {instrument_config.padded_x_dim//2+1}"
#     126 ]:
# --> 127     object_spectrum_at_exit_plane = self.compute_object_spectrum_at_exit_plane(
#     128         instrument_config, rng_key
#     129     )
#     130     contrast_spectrum_at_detector_plane = self.transfer_theory.propagate_object_to_detector_plane(  # noqa: E501
#     131         object_spectrum_at_exit_plane,
#     132         instrument_config,
#     133         is_projection_approximation=self.potential_integrator.is_projection_approximation,
#     134     )
#     135     # ... apply in-plane translation
#
#     [... skipping hidden 1 frame]
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/cryojax/simulator/_scattering_theory/weak_phase_scattering_theory.py:100, in WeakPhaseScatteringTheory.compute_object_spectrum_at_exit_plane(self, instrument_config, rng_key)
#      90 @override
#      91 def compute_object_spectrum_at_exit_plane(
#      92     self,
#    (...)     97 ]:
#      98     # Compute the phase shifts in the exit plane
#      99     object_spectrum_at_exit_plane = (
# --> 100         _compute_object_spectrum_from_scattering_potential(
#     101             self.structural_ensemble, self.potential_integrator, instrument_config
#     102         )
#     103     )
#     105     if rng_key is not None:
#     106         # Get the potential of the specimen plus the ice
#     107         if self.solvent is not None:
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/cryojax/simulator/_scattering_theory/weak_phase_scattering_theory.py:330, in _compute_object_spectrum_from_scattering_potential(structural_ensemble, potential_integrator, instrument_config)
#     327 potential = structural_ensemble.get_potential_in_lab_frame()
#     328 # Compute the phase shifts in the exit plane
#     329 fourier_integrated_potential = (
# --> 330     potential_integrator.compute_fourier_integrated_potential(
#     331         potential, instrument_config
#     332     )
#     333 )
#     334 # Compute the phase shifts in exit plane and multiply by the translation.
#     335 phase_shifts_in_exit_plane = convert_units_of_integrated_potential(
#     336     fourier_integrated_potential, instrument_config.wavelength_in_angstroms
#     337 )
#
#     [... skipping hidden 1 frame]
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/cryojax/simulator/_potential_integrator/atom_potential_integrator.py:106, in GaussianMixtureProjection.compute_fourier_integrated_potential(self, potential, instrument_config)
#     101     raise ValueError(
#     102         "Supported types for `potential` are `PengAtomicPotential` and "
#     103         "`GaussianMixtureAtomicPotential`."
#     104     )
#     105 # Compute the projection
# --> 106 projection = _compute_projected_potential_from_atoms(
#     107     shape,
#     108     pixel_size,
#     109     potential.atom_positions,
#     110     gaussian_amplitudes,
#     111     gaussian_widths,
#     112     self.use_error_functions,
#     113     self.n_batches,
#     114 )
#     115 if self.upsampling_factor is not None:
#     116     # Downsample back to the original pixel size, rescaling so that the
#     117     # downsampling produces an average in a given region, not a sum
#     118     n_pixels, upsampled_n_pixels = instrument_config.n_pixels, math.prod(shape)
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/cryojax/simulator/_potential_integrator/atom_potential_integrator.py:164, in _compute_projected_potential_from_atoms(shape, pixel_size, atom_positions, a, b, use_error_functions, n_batches)
#     157     raise ValueError(
#     158         "The `n_batches` when computing a projection must "
#     159         "be an integer less than or equal to the number of atoms, "
#     160         f"which is equal to {atom_positions.shape[0]}. Got "
#     161         f"`n_batches = {n_batches}`."
#     162     )
#     163 elif n_batches == 1:
# --> 164     projection = compute_potential_for_atom_group(xs)
#     165 elif n_batches > 1:
#     166     projection = jnp.sum(
#     167         _batched_map_with_contraction(
#     168             compute_potential_for_atom_group, xs, n_batches
#     169         ),
#     170         axis=0,
#     171     )
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/cryojax/simulator/_potential_integrator/atom_potential_integrator.py:145, in _compute_projected_potential_from_atoms.<locals>.<lambda>(xs)
#     142 # Get function and pytree to compute potential over a batch of atoms
#     143 xs = (atom_positions, a, b)
#     144 compute_potential_for_atom_group = (
# --> 145     lambda xs: _compute_projected_potential_from_atom_group(
#     146         grid_x,
#     147         grid_y,
#     148         pixel_size,
#     149         xs[0],
#     150         xs[1],
#     151         xs[2],
#     152         use_error_functions,
#     153     )
#     154 )
#     155 # Compute projection with a call to `jax.lax.map` in batches
#     156 if n_batches > atom_positions.shape[0]:
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/cryojax/simulator/_potential_integrator/atom_potential_integrator.py:196, in _compute_projected_potential_from_atom_group(grid_x, grid_y, pixel_size, atom_positions, a, b, use_error_functions)
#     192     result = _compute_gaussian_integrals_for_all_atoms(
#     193         grid_x, grid_y, atom_positions, a, b, pixel_size
#     194     )
#     195 else:
# --> 196     result = _compute_gaussians_for_all_atoms(grid_x, grid_y, atom_positions, a, b)
#     197 gaussians_times_prefactor_x, gaussians_y = result
#     198 projection = _compute_projected_potential_from_gaussians(
#     199     gaussians_times_prefactor_x, gaussians_y
#     200 )
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/cryojax/simulator/_potential_integrator/atom_potential_integrator.py:268, in _compute_gaussians_for_all_atoms(grid_x, grid_y, atom_positions, a, b)
#     256 def _compute_gaussians_for_all_atoms(
#     257     grid_x: Float[Array, " x_dim"],
#     258     grid_y: Float[Array, " y_dim"],
#    (...)    264     Float[Array, "dim_y n_atoms n_gaussians_per_atom"],
#     265 ]:
#     266     b_inverse = 4.0 * jnp.pi / b
#     267     gauss_x = jnp.exp(
# --> 268         -jnp.pi
#     269         * b_inverse[None, :, :]
#     270         * ((grid_x[:, None] - atom_positions.T[0, :]) ** 2)[:, :, None]
#     271     )
#     272     gauss_y = jnp.exp(
#     273         -jnp.pi
#     274         * b_inverse[None, :, :]
#     275         * ((grid_y[:, None] - atom_positions.T[1, :]) ** 2)[:, :, None]
#     276     )
#     277     prefactor = 4 * jnp.pi * a[None, :, :] * b_inverse[None, :, :]
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:1060, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1059 def op(self, *args):
# -> 1060   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:579, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     577 args = (other, self) if swap else (self, other)
#     578 if isinstance(other, _accepted_binop_types):
# --> 579   return binary_op(*args)
#     580 # Note: don't use isinstance here, because we don't want to raise for
#     581 # subclasses, e.g. NamedTuple objects that may override operators.
#     582 if type(other) in _rejected_binop_types:
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/jax/_src/numpy/ufunc_api.py:180, in ufunc.__call__(self, out, where, *args)
#     178   raise NotImplementedError(f"where argument of {self}")
#     179 call = self.__static_props['call'] or self._call_vectorized
# --> 180 return call(*args)
#
#     [... skipping hidden 16 frame]
#
# File ~/venvs/ensemble_sim/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:1297, in ExecuteReplicated.__call__(self, *args)
#    1295   self._handle_token_bufs(result_token_bufs, sharded_runtime_token)
#    1296 else:
# -> 1297   results = self.xla_executable.execute_sharded(input_bufs)
#    1299 if dispatch.needs_check_special():
#    1300   out_arrays = results.disassemble_into_single_device_arrays()
#
# XlaRuntimeError: RESOURCE_EXHAUSTED: Out of memory while trying to allocate 4996096000 bytes.

# %%
fig, axes = plt.subplots(3, 3, figsize=(5, 5))
for idx, ax in enumerate(axes.reshape(-1)):
    ax.imshow(noised_images[idx,:], cmap="gray")
    ax.set_yticks([])
    ax.set_xticks([])
#plt.savefig(f"figures/noised_images", dpi=300)

# %% [markdown]
# ## Checking the conformation idx of each individual image
# This is a quick check that the sampled conformations actually match the distribution we specified, and a simple use of the per-image conformation info we are tracking

# %%
# this is reading out the true conformation index of each image
conformations = extra_info["conformation"]

# compute pdf output on a 1d grid
x = jnp.linspace(0, 19, 20)
dx = x[1] - x[0]
    
# normalize output to integrate to 1 on the grid 
weights = jnp.exp(mixture.log_prob(x))
weights /= weights.sum()
plt.plot(x, weights, label='true', color="C0")
plt.hist(conformations, bins=20, range=(0, 19), density=True, label='conformations', color="C1")
plt.xticks(jnp.arange(0, 20, 2))
plt.xlabel('pdb index')
plt.ylabel('Probability')  
plt.legend()
plt.show()
